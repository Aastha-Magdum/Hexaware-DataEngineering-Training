# %%
from pyspark.sql import SparkSession

spark=SparkSession.builder \
.appName("Basic Dataset") \
.getOrCreate()

# %%
sales_data = [
(1001,"Laptop","Electronics","Hyderabad",2,65000,"Completed"),
(1002,"Mobile","Electronics","Bangalore",3,25000,"Completed"),
(1003,"Chair","Furniture","Mumbai",5,3500,"Pending"),
(1004,"Table","Furniture","Delhi",2,12000,"Completed"),
(1005,"Shoes","Fashion","Chennai",4,2500,"Completed"),
(1006,"Watch","Fashion","Pune",1,8000,"Cancelled"),
(1007,"TV","Electronics","Hyderabad",1,45000,"Completed"),
(1008,"Laptop","Electronics","Mumbai",2,65000,"Completed"),
(1009,"Chair","Furniture","Delhi",3,3500,"Pending"),
(1010,"Shoes","Fashion","Bangalore",5,2500,"Completed"),
(1011,"Mobile","Electronics","Chennai",4,25000,"Completed"),
(1012,"Watch","Fashion","Hyderabad",2,8000,"Completed"),
(1013,"TV","Electronics","Delhi",1,45000,"Completed"),
(1014,"Table","Furniture","Pune",3,12000,"Cancelled"),
(1015,"Laptop","Electronics","Bangalore",1,65000,"Completed"),
(1016,"Mobile","Electronics","Mumbai",2,25000,"Completed"),
(1017,"Shoes","Fashion","Delhi",4,2500,"Pending"),
(1018,"Chair","Furniture","Hyderabad",2,3500,"Completed"),
(1019,"TV","Electronics","Chennai",1,45000,"Completed"),
(1020,"Watch","Fashion","Bangalore",3,8000,"Completed")
]
columns = [
"order_id",
"product",
"category",
"city",
"quantity",
"price",
"status"
]
df = spark.createDataFrame(
sales_data,
columns

)
display(df)

# %%
df.show()

# %%
df.printSchema()

# %%
from pyspark.sql.functions import *

# %%
df.show(10)

# %%
df.select("product","price").show()

# %%
df.select("category","city").show()

# %%
#6
df.count()

# %%
#7
len(df.columns)

# %%
#8
df.select("city").distinct().show()

# %%
#9
df.select("category").distinct().show()

# %%
#10
df.select("status").distinct().show()

# %%
#11
df.filter(df.category=="Electronics").show()

# %%
#12
df.filter(df.category=="Furniture").show()

# %%
#13
df.filter(df.category == "Fashion").show()

# %%
#14
df.filter(df.city == "Hyderabad").show()

# %%
#15
df.filter(df.city == "Bangalore").show()

# %%
#16
df.filter(df.status == "Completed").show()

# %%
#17
df.filter(df.status == "Pending").show()

# %%
#18
df.filter(df.status == "Cancelled").show()

# %%
#19
df.filter(df.price>30000).show()

# %%
#20
df.filter(df.quantity > 2).show()

# %%
#21
df.filter((df.category=="Electronics") & (df.city=="Hyderabad")).show()

# %%
#22
df.filter((df.category == "Furniture") & (df.city == "Delhi")).show()

# %%
#23
df.filter((df.category == "Fashion") & (df.city == "Bangalore")).show()

# %%
#24
df.filter((df.city == "Hyderabad") | (df.city == "Mumbai")).show()

# %%
#25
df.filter(df.price.between(10000,50000)).show()

# %%
#26
df.orderBy("price").show()

# %%
#27
df.orderBy(df.price.desc()).show()

# %%
#28
df.orderBy(df.quantity.desc()).show()

# %%
#29
df.orderBy("city","price").show()

# %%
#30
df.orderBy("category", "product").show()

# %%
#31
df.withColumn("total_amount", df.quantity * df.price).show()

# %%
#32
df.withColumn("tax", (df.quantity * df.price) * 0.05).show()

# %%
#33
df.withColumn(
    "final_amount",
    (df.quantity * df.price) + ((df.quantity * df.price) * 0.05)
).show()

# %%
#34
df.withColumn("discount",(df.quantity * df.price) * 0.10).show()

# %%
#35
df.withColumn(
    "net_amount",
    (df.quantity * df.price) - ((df.quantity * df.price) * 0.10)
).show()

# %%
#36
df.withColumnRenamed("price","unit_price").show()

# %%
#37
df.withColumnRenamed("status", "order_status").show()

# %%
#38
df.drop("category").show()

# %%
#39
df.drop("city").show()

# %%
#40
copy_df = (
    df.withColumn("total_amount", df.quantity * df.price)
      .withColumn("tax", (df.quantity * df.price) * 0.05)
      .withColumn("discount", (df.quantity * df.price) * 0.10)
)
copy_df.show()

# %%
#41
df.groupBy('city').count().show()

# %%
#42
df.groupBy("category").count().show()

# %%
#43
df.groupBy("status").count().show()

# %%
#44
df.withColumn(
    "revenue",
    df.quantity * df.price
).groupBy("city").sum("revenue").show()

# %%
#45
df.withColumn(
    "revenue",
    df.quantity * df.price
).groupBy("category").sum("revenue").show()

# %%
#46
df.withColumn(
    "revenue",
    df.quantity * df.price
).groupBy("product").sum("revenue").show()

# %%
#47
df.groupBy("category").avg("price").show()

# %%
#48
df.groupBy("category").max("price").show()

# %%
#49
df.groupBy("category").min("price").show()

# %%
#50
df.groupBy("product").sum("quantity").show()

# %%
from pyspark.sql.window import Window

# %%
#51
df.select(upper("product")).show()

# %%
#52
df.select(lower("product")).show()

# %%
#53
df.select("product",length("product")).show()

# %%
#54
df.select(substring("product",1,3)).show()

# %%
#55
df.select(concat("city", "category")).show()

# %%
#56
df.withColumn("city_category",concat_ws("_", "city", "category")).show()

# %%
#57
df.withColumn("category",regexp_replace("category","Electronics","Electronic Items")).show()

# %%
#58
df.withColumn("product_code", substring("product", 1, 3)).show()

# %%
#59
df.withColumn("product", trim("product")).show()

# %%
#60
df.filter(col("product").contains("a")).show()

# %%
#61
df.withColumn(
    "price_band",
    when(col("price") >= 50000, "Premium")
    .when(col("price") >= 10000, "Standard")
    .otherwise("Budget")
).show()

# %%
#62
df.withColumn(
    "price_band",
    when(col("price") >= 50000, "Premium")
    .when(col("price") >= 10000, "Standard")
    .otherwise("Budget")
).groupBy("price_band").count().show()

# %%
#63
df.withColumn(
    "order_size",
    when(col("quantity") >= 4, "Large")
    .otherwise("Small")
).show()

# %%
#64
df.withColumn(
    "order_size",
    when(col("quantity") >= 4, "Large")
    .otherwise("Small")
).groupBy("order_size").count().show()

# %%
#65
df.withColumn(
    "total_amount",
    col("quantity") * col("price")
).withColumn(
    "revenue_band",
    when(col("total_amount") >= 100000, "High")
    .otherwise("Low")
).show()

# %%
#66
df.createOrReplaceTempView("sales")

# %%
#67
spark.sql("select * from sales").show()

# %%
#68
spark.sql("""
select city, count(*) as total_orders
from sales
group by city
""").show()

# %%
#69
spark.sql("""
select category, count(*) as total_orders
from sales
group by category
""").show()

# %%
#70
spark.sql("""
select city,
sum(quantity * price) as revenue
from sales
group by city
""").show()

# %%
#71
spark.sql("""
select category,
sum(quantity * price) as revenue
from sales
group by category
""").show()

# %%
#72
spark.sql("""
select *,
(quantity * price) as revenue
from sales
order by revenue desc
limit 5
""").show()

# %%
#73
spark.sql("""
select *
from sales
where status = 'Completed'
""").show()

# %%
#74
spark.sql("""
select category,
avg(price) as avg_price
from sales
group by category
""").show()

# %%
#75
spark.sql("""
select city,
sum(quantity * price) as revenue
from sales
group by city
order by revenue desc
limit 1
""").show()

# %%
#76
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy(col("revenue").desc())

revenue_df.withColumn(
    "row_number",
    row_number().over(window_spec)
).show()

# %%
#77
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy(col("revenue").desc())

revenue_df.withColumn(
    "rank",
    rank().over(window_spec)
).show()

# %%
#78
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy(col("revenue").desc())

revenue_df.withColumn(
    "dense_rank",
    dense_rank().over(window_spec)
).show()

# %%
#79
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy(col("revenue").desc())

revenue_df.withColumn(
    "row_number",
    row_number().over(window_spec)
).filter(col("row_number") <= 5).show()

# %%
#80
df.withColumn(
    "revenue",
    col("quantity") * col("price")
).orderBy(col("revenue").desc()).limit(1).show()

# %%
#81
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.partitionBy("city").orderBy(col("revenue").desc())

revenue_df.withColumn(
    "rank",
    row_number().over(window_spec)
).filter(col("rank") == 1).show()

# %%
#82
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.partitionBy("category").orderBy(col("revenue").desc())

revenue_df.withColumn(
    "rank",
    row_number().over(window_spec)
).filter(col("rank") == 1).show()

# %%
#83
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy("order_id")

revenue_df.withColumn(
    "running_total",
    sum("revenue").over(window_spec)
).show()

# %%
#84
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy("order_id")

revenue_df.withColumn(
    "previous_revenue",
    lag("revenue").over(window_spec)
).show()

# %%
#85
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy("order_id")

revenue_df.withColumn(
    "next_revenue",
    lead("revenue").over(window_spec)
).show()

# %%
#86
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy("order_id")

revenue_df.withColumn(
    "previous_revenue",
    lag("revenue").over(window_spec)
).withColumn(
    "comparison",
    col("revenue") - col("previous_revenue")
).show()

# %%
#87
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy("order_id")

revenue_df.withColumn(
    "previous_revenue",
    lag("revenue").over(window_spec)
).withColumn(
    "revenue_difference",
    col("revenue") - col("previous_revenue")
).show()

# %%
#88
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.partitionBy("city").orderBy(col("revenue").desc())

revenue_df.withColumn(
    "rank",
    row_number().over(window_spec)
).filter(col("rank") <= 2).show()

# %%
#89
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.partitionBy("category").orderBy(col("revenue").desc())

revenue_df.withColumn(
    "rank",
    row_number().over(window_spec)
).filter(col("rank") <= 3).show()

# %%
#90
revenue_df = df.withColumn("revenue", col("quantity") * col("price"))

window_spec = Window.orderBy(col("revenue").desc())

revenue_df.withColumn(
    "revenue_rank",
    dense_rank().over(window_spec)
).show()

# %%
#91
source_df = df
source_df.show()

# %%
#92
etl_df = df.withColumn(
    "total_amount",
    col("quantity") * col("price")
)

etl_df.show()

# %%
#93
df.filter(col("status") == "Completed").show()

# %%
#94
df.withColumn(
    "revenue",
    col("quantity") * col("price")
).show()

# %%
#95
df.withColumn(
    "revenue",
    col("quantity") * col("price")
).groupBy("city").sum("revenue").show()

# %%
#96
df.withColumn(
    "revenue",
    col("quantity") * col("price")
).groupBy("category").sum("revenue").show()

# %%
#97
df.write.mode("overwrite").parquet("sales_parquet")

# %%
#98
parquet_df = spark.read.parquet("sales_parquet")

parquet_df.show()

# %%
#99
parquet_df.createOrReplaceTempView("sales_parquet_view")

# %%
#100
spark.sql("""
select
category,
city,
sum(quantity * price) as revenue
from sales_parquet_view
group by category, city
order by revenue desc
""").show()
