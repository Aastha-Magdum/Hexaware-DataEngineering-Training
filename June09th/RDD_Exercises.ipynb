# %%
from pyspark.sql import SparkSession

spark=SparkSession.builder \
.appName("RDD Exercise") \
.getOrCreate()

# %%
activities = [
"LOGIN",
"COURSE_VIEW",
"LOGIN",
"VIDEO_PLAY",
"QUIZ_START",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"ASSIGNMENT_SUBMIT",
"VIDEO_PLAY",
"QUIZ_START",
"QUIZ_COMPLETE",
"LOGIN",
"VIDEO_PLAY",
"COURSE_VIEW",
"LOGIN",
"VIDEO_PLAY",
"VIDEO_PLAY",
"QUIZ_START",
"LOGIN",
"COURSE_VIEW",
"COURSE_VIEW",
"ASSIGNMENT_SUBMIT",
"LOGIN",
"VIDEO_PLAY",
"QUIZ_COMPLETE",
"LOGIN",
"COURSE_VIEW",
"VIDEO_PLAY",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"QUIZ_START",
"ASSIGNMENT_SUBMIT",
"LOGIN",

"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"QUIZ_COMPLETE",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"VIDEO_PLAY",
"LOGIN",
"QUIZ_START",
"COURSE_VIEW",
"VIDEO_PLAY",
"ASSIGNMENT_SUBMIT",
"LOGIN",
"VIDEO_PLAY"
]
rdd = spark.sparkContext.parallelize(activities)

# %%
#1
print(rdd.collect())

# %%
#2
print(rdd.count())

# %%
#3
res = rdd.first()
print(res)

# %%
#4
res = rdd.take(10)
print(res)

# %%
#5
res=rdd.collect()
print(res[-1])

# %%
#6
res = rdd.distinct()
print(res.collect())

# %%
#7
res = rdd.distinct().count()
print(res)

# %%
#8
res = rdd.sortBy(lambda x: x)
print(res.collect())

# %%
#9
res=rdd.map(
    lambda x:x.upper()
    )
print(res.collect())

# %%
#10
res=rdd.map(lambda x: (x,len(x)))
print(res.collect())

# %%
#11
res = rdd.filter(lambda x: x == "LOGIN")
print(res.collect())

# %%
#12
res = rdd.filter(lambda x: x == "VIDEO_PLAY")
print(res.collect())

# %%
#13
res = rdd.filter(lambda x: x == "QUIZ_START")
print(res.collect())

# %%
#14
res = rdd.filter(lambda x: "QUIZ" in x)
print(res.collect())

# %%
#15
res = rdd.filter(lambda x: x.endswith("VIEW"))
print(res.collect())

# %%
#16
res = rdd.filter(lambda x: x != "LOGIN")
print(res.collect())

# %%
#17
res = rdd.filter(lambda x: x != "VIDEO_PLAY")
print(res.collect())

# %%
#18
res = rdd.filter(lambda x: len(x) > 8)
print(res.collect())

# %%
#19
res = rdd.filter(lambda x: len(x) < 10)
print(res.collect())

# %%
#20
res = rdd.filter(lambda x: x.startswith("C"))
print(res.collect())

# %%
#21
res = rdd.map(lambda x: x.lower())
print(res.collect())

# %%
#22
res = rdd.map(lambda x: "EVENT_" + x)
print(res.collect())

# %%
#23
res = rdd.map(lambda x: x + "_2025")
print(res.collect())

# %%
#24
res = rdd.map(lambda x: len(x))
print(res.collect())

# %%
#25
res = rdd.map(lambda x: (x, len(x)))
print(res.collect())

# %%
#26
res = rdd.map(lambda x: (x, 1))
print(res.collect())

# %%
#27
res = rdd.map(lambda x: "USER_LOGIN" if x == "LOGIN" else x)
print(res.collect())

# %%
#28
res = rdd.map(lambda x: "WATCH_VIDEO" if x == "VIDEO_PLAY" else x)
print(res.collect())

# %%
#29
res = rdd.map(lambda x: x[::-1])
print(res.collect())

# %%
#30
res = rdd.map(lambda x: x[0])
print(res.collect())

# %%
#31
res = rdd.distinct()
print(res.collect())

# %%
#32
res = rdd.distinct().count()
print(res)

# %%
#33
res = rdd.distinct().sortBy(lambda x: x)
print(res.collect())

# %%
#34
res = rdd.distinct().filter(lambda x: "QUIZ" in x)
print(res.collect())

# %%
#35
res = rdd.distinct().filter(lambda x: "COURSE" in x)
print(res.collect())

# %%
#36
res = rdd.countByValue()
print(res)

# %%
#37
res = rdd.countByValue()
print(max(res.items(), key=lambda x: x[1]))

# %%
#38
res = rdd.countByValue()
print(min(res.items(), key=lambda x: x[1]))

# %%
#39
res = rdd.countByValue()
print(sorted(res.items(), key=lambda x: x[1]))

# %%
#40
res = rdd.countByValue()

for activity, count in res.items():
    if count > 5:
        print(activity, count)

# %%
extra_activities = [
    "LOGIN",
    "CERTIFICATE_DOWNLOAD",
    "VIDEO_PLAY",
    "PROFILE_UPDATE",
    "QUIZ_COMPLETE"
]

rdd2 = spark.sparkContext.parallelize(extra_activities)

# %%
#41
res = rdd.union(rdd2)
print(res.collect())

# %%
#42
res = rdd.union(rdd2)
print(res.count())

# %%
#43
res = rdd.union(rdd2).distinct()
print(res.collect())

# %%
#44
res = rdd.union(rdd2)
print(res.countByValue())

# %%
#45
res = rdd2.subtract(rdd)
print(res.collect())

# %%
rdd3 = spark.sparkContext.parallelize([
    "LOGIN",
    "COURSE_VIEW",
    "PROFILE_UPDATE",
    "QUIZ_COMPLETE",
    "PAYMENT_SUCCESS"
])

# %%
#46
res = rdd.intersection(rdd3)
print(res.collect())

# %%
#47
res = rdd.intersection(rdd3)
print(res.count())

# %%
#48
res = rdd.intersection(rdd3).sortBy(lambda x: x)
print(res.collect())

# %%
#49
res = rdd.intersection(rdd3).filter(lambda x: "QUIZ" in x)
print(res.collect())

# %%
#50
res = rdd.intersection(rdd3).filter(lambda x: "LOGIN" in x)
print(res.collect())

# %%
numbers = [
120,
250,
300,
450,
600,
750,
900,
1050,
1200,
1350,
1500,
1650,
1800,
1950,
2100
]
sales_rdd = spark.sparkContext.parallelize(numbers)

# %%
#51
res = sales_rdd.reduce(lambda x, y: x + y)
print(res)

# %%
#52
res = sales_rdd.reduce(lambda x, y: x if x > y else y)
print(res)

# %%
#53
res = sales_rdd.reduce(lambda x, y: x if x < y else y)
print(res)

# %%
#54
total = sales_rdd.reduce(lambda x, y: x + y)
count = sales_rdd.count()
print(total / count)

# %%
#55
res = sales_rdd.filter(lambda x: x > 1000)
print(res.count())

# %%
#56
res = sales_rdd.map(lambda x: x * 2)
print(res.collect())

# %%
#57
res = sales_rdd.map(lambda x: x + 100)
print(res.collect())

# %%
#58
res = sales_rdd.sortBy(lambda x: x)
print(res.collect())

# %%
#59
res = sales_rdd.sortBy(lambda x: x, ascending=False)
print(res.collect())

# %%
#60
res = sales_rdd.top(5)
print(res)

# %%
courses = [
    "Python SQL Spark",
    "Azure Databricks Spark",
    "Python Pandas NumPy",
    "SQL Spark DeltaLake",
    "Azure Python SQL"
]

course_rdd = spark.sparkContext.parallelize(courses)

# %%
#61
res = course_rdd.flatMap(lambda x: x.split())
print(res.collect())

# %%
#62
res = course_rdd.flatMap(lambda x: x.split())
print(res.count())

# %%
#63
res = course_rdd.flatMap(lambda x: x.split()).distinct()
print(res.collect())

# %%
#64
res = course_rdd.flatMap(lambda x: x.split()).sortBy(lambda x: x)
print(res.collect())

# %%
#65
res = course_rdd.flatMap(lambda x: x.split()).countByValue()
print(res)

# %%
#66
res = course_rdd.flatMap(lambda x: x.split()).filter(lambda x: "Python" in x)
print(res.collect())

# %%
#67
res = course_rdd.flatMap(lambda x: x.split()).filter(lambda x: "Spark" in x)
print(res.collect())

# %%
#68
res = course_rdd.flatMap(lambda x: x.split()).map(lambda x: x.upper())
print(res.collect())

# %%
#69
res = course_rdd.flatMap(lambda x: x.split())
print(res.reduce(lambda x, y: x if len(x) > len(y) else y))

# %%
#70
res = course_rdd.flatMap(lambda x: x.split())
print(res.reduce(lambda x, y: x if len(x) < len(y) else y))

# %%
#71
res = rdd.countByValue()
print(max(res.items(), key=lambda x: x[1]))

# %%
#72
res = rdd.countByValue()
print(min(res.items(), key=lambda x: x[1]))

# %%
#73
login_count = rdd.filter(lambda x: x == "LOGIN").count()
total_count = rdd.count()

print((login_count / total_count) * 100)

# %%
#74
video_count = rdd.filter(lambda x: x == "VIDEO_PLAY").count()
total_count = rdd.count()

print((video_count / total_count) * 100)

# %%
#75
total_records = rdd.count()
unique_records = rdd.distinct().count()

print("Activity Report")
print("Total Activities :", total_records)
print("Unique Activities :", unique_records)

# %%
#76
res = rdd.distinct().sortBy(lambda x: x)

print("Unique Activity Report")
for activity in res.collect():
    print(activity)

# %%
#77
res = rdd.countByValue()

print("Frequency Report")
for activity, count in res.items():
    print(activity, ":", count)

# %%
#78
res = rdd.distinct()

res.saveAsTextFile("distinct_activities")

# %%
#79
res = rdd.map(lambda x: (x, 1))
res = res.reduceByKey(lambda x, y: x + y)

res.saveAsTextFile("activity_frequencies")

# %%
#80
total_records = rdd.count()

unique_records = rdd.distinct().count()

most_common = max(
    rdd.countByValue().items(),
    key=lambda x: x[1]
)

least_common = min(
    rdd.countByValue().items(),
    key=lambda x: x[1]
)

print("Learning Platform Usage Summary")
print("Total Activities :", total_records)
print("Unique Activities :", unique_records)
print("Most Common Activity :", most_common)
print("Least Common Activity :", least_common)
