# %%
from pyspark.sql import SparkSession

spark=SparkSession.builder \
.appName("RDD Bank Transaction") \
.getOrCreate()

# %%
transactions = [
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",

"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT"
]
rdd = spark.sparkContext.parallelize(transactions)

# %%
#1
res = rdd.collect()
print(res)

# %%
#2
res = rdd.count()
print(res)

# %%
#3
res = rdd.first()
print(res)

# %%
#4
res = rdd.take(15)
print(res)

# %%
#5
res = rdd.distinct()
print(res.collect())

# %%
#6
res = rdd.distinct().count()
print(res)

# %%
#7
res = rdd.sortBy(lambda x: x)
print(res.collect())

# %%
#8
res = rdd.map(lambda x: x.lower())
print(res.collect())

# %%
#9
res = rdd.map(lambda x: x.upper())
print(res.collect())

# %%
#10
res = rdd.map(lambda x: len(x))
print(res.collect())

# %%
#11
res = rdd.filter(lambda x: x == "DEPOSIT")
print(res.collect())

# %%
#12
res = rdd.filter(lambda x: x == "WITHDRAW")
print(res.collect())

# %%
#13
res = rdd.filter(lambda x: x == "TRANSFER")
print(res.collect())

# %%
#14
res = rdd.filter(lambda x: x == "LOAN_PAYMENT")
print(res.collect())

# %%
#15
res = rdd.filter(lambda x: "CHECK" in x)
print(res.collect())

# %%
#16
res = rdd.filter(lambda x: x != "DEPOSIT")
print(res.collect())

# %%
#17
res = rdd.filter(lambda x: x != "TRANSFER")
print(res.collect())

# %%
#18
res = rdd.filter(lambda x: len(x) > 8)
print(res.collect())

# %%
#19
res = rdd.filter(lambda x: len(x) < 10)
print(res.collect())

# %%
#20
res = rdd.filter(lambda x: x.startswith("B"))
print(res.collect())

# %%
#21
res = rdd.map(lambda x: "BANK_" + x)
print(res.collect())

# %%
#22
res = rdd.map(lambda x: x + "_2025")
print(res.collect())

# %%
#23
res = rdd.map(lambda x: (x, len(x)))
print(res.collect())

# %%
#24
res = rdd.map(lambda x: (x, 1))
print(res.collect())

# %%
#25
res = rdd.map(lambda x: "CASH_DEPOSIT" if x == "DEPOSIT" else x)
print(res.collect())

# %%
#26
res = rdd.map(lambda x: "CASH_WITHDRAWAL" if x == "WITHDRAW" else x)
print(res.collect())

# %%
#27
res = rdd.map(lambda x: x[::-1])
print(res.collect())

# %%
#28
res = rdd.map(lambda x: x[:3])
print(res.collect())

# %%
#29
res = rdd.map(lambda x: x[-4:])
print(res.collect())

# %%
#30
res = rdd.map(lambda x:
              "D" if x == "DEPOSIT"
              else "W" if x == "WITHDRAW"
              else "T" if x == "TRANSFER"
              else x)
print(res.collect())

# %%
#31
res = rdd.distinct()
print(res.collect())

# %%
#32
res = rdd.distinct().count()
print(res)

# %%
#33
res = rdd.distinct().sortBy(lambda x: x)
print(res.collect())

# %%
#34
res = rdd.distinct().filter(lambda x: "PAYMENT" in x)
print(res.collect())

# %%
#35
res = rdd.distinct().filter(lambda x: "CHECK" in x)
print(res.collect())

# %%
#36
res = rdd.countByValue()
print(res)

# %%
#37
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.max(key=lambda x: x[1]))

# %%
#38
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.min(key=lambda x: x[1]))

# %%
#39
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.collect())

# %%
#40
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.filter(lambda x: x[1] > 5).collect())

# %%
extra_transactions = [
"DEPOSIT",
"ATM_WITHDRAWAL",
"TRANSFER",

"MOBILE_RECHARGE",
"BALANCE_CHECK"
]
rdd2 = spark.sparkContext.parallelize(extra_transactions)

# %%
#41
res = rdd.union(rdd2)
print(res.collect())

# %%
#42
res = rdd.union(rdd2)
print(res.count())

# %%
#43
res = rdd.union(rdd2).distinct()
print(res.collect())

# %%
#44
res = rdd2.subtract(rdd)
print(res.collect())

# %%
#45
res = rdd.union(rdd2).map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.collect())

# %%
rdd3 = spark.sparkContext.parallelize([
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"CREDIT_CARD_PAYMENT",
"ATM_WITHDRAWAL"
])

# %%
#46
res = rdd.intersection(rdd3)
print(res.collect())

# %%
#47
res = rdd.intersection(rdd3)
print(res.count())

# %%
#48
res = rdd.intersection(rdd3).sortBy(lambda x: x)
print(res.collect())

# %%
#49
res = rdd.intersection(rdd3).filter(lambda x: "CHECK" in x)
print(res.collect())

# %%
#50
res = rdd.intersection(rdd3).filter(lambda x: "TRANSFER" in x)
print(res.collect())

# %%
amounts = [
500,1200,3000,4500,800,950,
1100,2500,4000,6000,

750,1800,2200,3300,4700,
5200,1500,2600,3700,4800,
5900,6200,700,900,1400,
1750,2100,2900,3600,4300,
5100,5800,6500,7200,8100,
9200,10500,12000,13500,15000,
17000,19000,22000,25000,28000,
30000,32000,35000,38000,40000
]
amount_rdd = spark.sparkContext.parallelize(amounts)

# %%
#51
res = amount_rdd.reduce(lambda x, y: x + y)
print(res)

# %%
#52
res = amount_rdd.reduce(lambda x, y: x + y) / amount_rdd.count()
print(res)

# %%
#53
res = amount_rdd.max()
print(res)

# %%
#54
res = amount_rdd.min()
print(res)

# %%
#55
res = amount_rdd.filter(lambda x: x > 10000)
print(res.collect())

# %%
#56
res = amount_rdd.filter(lambda x: x < 2000)
print(res.collect())

# %%
#57
res = amount_rdd.map(lambda x: x + 500)
print(res.collect())

# %%
#58
res = amount_rdd.map(lambda x: x * 1.10)
print(res.collect())

# %%
#59
res = amount_rdd.sortBy(lambda x: x)
print(res.collect())

# %%
#60
res = amount_rdd.sortBy(lambda x: x, ascending=False)
print(res.collect())

# %%
#61
res = amount_rdd.top(10)
print(res)

# %%
#62
res = amount_rdd.takeOrdered(10)
print(res)

# %%
#63
res = amount_rdd.filter(lambda x: x > 5000)
print(res.count())

# %%
#64
res = amount_rdd.filter(lambda x: x > 20000)
print(res.count())

# %%
#65
res = amount_rdd.filter(lambda x: x > 10000)
print(res.reduce(lambda x, y: x + y))

# %%
customer_comments = [
"service was excellent",
"mobile banking is easy",
"transfer completed quickly",
"deposit process was smooth",
"excellent customer support",
"loan payment completed successfully",
"banking app is excellent",
"service is fast and reliable"
]
comment_rdd = spark.sparkContext.parallelize(customer_comments)

# %%
#66
res = comment_rdd.flatMap(lambda x: x.split())
print(res.collect())

# %%
#67
res = comment_rdd.flatMap(lambda x: x.split())
print(res.count())

# %%
#68
res = comment_rdd.flatMap(lambda x: x.split()).distinct()
print(res.collect())

# %%
#69
res = comment_rdd.flatMap(lambda x: x.split()).sortBy(lambda x: x)
print(res.collect())

# %%
#70
res = comment_rdd.flatMap(lambda x: x.split()).map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.collect())

# %%
#71
res = comment_rdd.flatMap(lambda x: x.split()).filter(lambda x: "service" in x)
print(res.collect())

# %%
#72
res = comment_rdd.flatMap(lambda x: x.split()).filter(lambda x: "excellent" in x)
print(res.collect())

# %%
#73
res = comment_rdd.flatMap(lambda x: x.split()).map(lambda x: x.upper())
print(res.collect())

# %%
#74
res = comment_rdd.flatMap(lambda x: x.split())
print(res.max(key=len))

# %%
#75
res = comment_rdd.flatMap(lambda x: x.split())
print(res.min(key=len))

# %%
#76
res = comment_rdd.flatMap(lambda x: x.split()).map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.max(key=lambda x: x[1]))

# %%
#77
res = comment_rdd.flatMap(lambda x: x.split()).map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.min(key=lambda x: x[1]))

# %%
#78
res = comment_rdd.flatMap(lambda x: x.split()).filter(lambda x: x.startswith("b"))
print(res.count())

# %%
#79
res = comment_rdd.flatMap(lambda x: x.split()).filter(lambda x: x.endswith("ly"))
print(res.count())

# %%
#80
res = comment_rdd.flatMap(lambda x: x.split()).map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.collect())

# %%
#81
res = (rdd.filter(lambda x: x == "DEPOSIT").count() / rdd.count()) * 100
print(res)

# %%
#82
res = (rdd.filter(lambda x: x == "TRANSFER").count() / rdd.count()) * 100
print(res)

# %%
#83
res = (rdd.filter(lambda x: x == "WITHDRAW").count() / rdd.count()) * 100
print(res)

# %%
#84
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.max(key=lambda x: x[1]))

# %%
#85
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.min(key=lambda x: x[1]))

# %%
#86
res = {
    "Total Transactions": rdd.count(),
    "Unique Transactions": rdd.distinct().count()
}
print(res)

# %%
#87
res = rdd.distinct()
print(res.collect())

# %%
#88
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.collect())

# %%
#89
res = rdd.distinct()
res.saveAsTextFile("unique_transactions")

# %%
#90
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
res.saveAsTextFile("transaction_frequency")

# %%
#91
res = rdd.count()
print(res)

# %%
#92
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.takeOrdered(3, key=lambda x: -x[1]))

# %%
#93
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.takeOrdered(3, key=lambda x: x[1]))

# %%
#94
res = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
print(res.sortBy(lambda x: x[1], ascending=False).collect())

# %%
#95
res = {
    "Total": rdd.count(),
    "Unique": rdd.distinct().count(),
    "Most Common": rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).max(key=lambda x: x[1])
}
print(res)

# %%
#96
res = amount_rdd.reduce(lambda x, y: x + y)
print(res)

# %%
#97
res = amount_rdd.reduce(lambda x, y: x + y) / amount_rdd.count()
print(res)

# %%
#98
res = amount_rdd.filter(lambda x: x > 20000)
print(res.collect())

# %%
#99
res = amount_rdd.filter(lambda x: x < 1000)
print(res.collect())

# %%
#100
res = {
    "Total Activities": rdd.count(),
    "Unique Activities": rdd.distinct().count(),
    "Total Money": amount_rdd.reduce(lambda x, y: x + y),
    "Average Amount": amount_rdd.reduce(lambda x, y: x + y) / amount_rdd.count()
}
print(res)
